# %% [markdown]
# # 不同比例的词典的折线图

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

bc5cdr = [
    [73.41, 75.22, 74.30, 0.2, "MProto"],
    [72.32, 77.95, 75.03, 0.4, "MProto"],
    [76.31, 83.63, 79.80, 0.6, "MProto"],
    [77.42, 84.32, 80.72, 0.8, "MProto"],
    [77.53, 85.84, 81.47, 1.0, "MProto"],
    [78.93, 14.32, 24.25, 0.2, "NegSamp."],
    [76.85, 51.10, 61.38, 0.4, "NegSamp."],
    [77.09, 59.18, 66.96, 0.6, "NegSamp."],
    [79.17, 69.48, 74.01, 0.8, "NegSamp."],
    [79.30, 78.17, 78.73, 1.0, "NegSamp."],
    [78.42, 11.11, 19.47, 0.2, "ES"],
    [79.02, 33.75, 47.30, 0.4, "ES"],
    [81.77, 44.75, 57.85, 0.6, "ES"],
    [80.86, 58.56, 67.92, 0.8, "ES"],
    [82.06, 70.09, 75.60, 1.0, "ES"],
    [87.31, 12.09, 21.24, 0.2, "DS"],
    [87.66, 29.06, 43.65, 0.4, "DS"],
    [88.42, 40.02, 55.10, 0.6, "DS"],
    [89.42, 53.85, 67.22, 0.8, "DS"],
    [89.45, 66.95, 76.58, 1.0, "DS"],
]

df_bc5cdr = pd.DataFrame(bc5cdr, columns=["prec.", "rec.", "f1", "dsize", "model"])

plt.rcParams['figure.figsize'] = [4, 3]
#sns.lineplot(x="dsize", y="prec.", hue="model", style="model", markers=True, dashes=False, data=df_bc5cdr, legend=False, ax=axes[0])
# sns.lineplot(x="dsize", y="rec.", hue="model", style="model", markers=True, dashes=False, data=df_bc5cdr, legend=False, ax=axes[1])
sns.lineplot(x="dsize", y="f1", hue="model", style="model", markers=True, dashes=False, data=df_bc5cdr, legend=True)
plt.show()

# %%
conll03 = [
    [76.11, 70.50, 73.20, 0.2, "MProto"],
    [85.02, 75.78, 80.13, 0.4, "MProto"],
    [84.56, 77.96, 81.12, 0.6, "MProto"],
    [83.57, 78.61, 81.01, 0.8, "MProto"],
    [84.27, 80.79, 82.49, 1.0, "MProto"],
    [65.01, 17.40, 27.46, 0.2, "NegSamp."],
    [87.44, 42.28, 57.00, 0.4, "NegSamp."],
    [87.67, 53.88, 66.74, 0.6, "NegSamp."],
    [87.30, 61.83, 72.39, 0.8, "NegSamp."],
    [83.71, 67.78, 74.90, 1.0, "NegSamp."],
    [63.33, 9.63, 16.72, 0.2, "ES"],
    [77.98, 22.13, 34.48, 0.4, "ES"],
    [86.26, 34.67, 49.46, 0.6, "ES"],
    [85.41, 49.75, 62.88, 0.8, "ES"],
    [86.34, 55.74, 67.74, 1.0, "ES"],
    [81.49, 10.55, 18.67, 0.2, "DS"],
    [84.87, 20.65, 33.21, 0.4, "DS"],
    [87.58, 30.68, 45.44, 0.6, "DS"],
    [89.02, 42.42, 57.46, 0.8, "DS"],
    [91.62, 52.15, 66.47, 1.0, "DS"],
]


df_conll03 = pd.DataFrame(conll03, columns=["prec.", "rec.", "f1", "dsize", "model"])

plt.rcParams['figure.figsize'] = [4, 3]
sns.lineplot(x="dsize", y="f1", hue="model", style="model", markers=True, dashes=False, data=df_conll03, legend=False)
plt.show()

# %% [markdown]
# # 不同的原型数目的折线图

# %%
bc5cdr = [
    [73.41, 75.22, 74.30, 1],
    [72.32, 77.95, 75.03, 2],
    [76.31, 83.63, 79.80, 3],
    [77.42, 84.32, 80.72, 4],
    [77.53, 85.84, 81.47, 5],
    [77.53, 85.84, 81.47, 6],
]

df_bc5cdr = pd.DataFrame(bc5cdr, columns=["prec.", "rec.", "f1", "#proto"])

plt.rcParams['figure.figsize'] = [4, 3]
sns.lineplot(x="#proto", y="f1", data=df_bc5cdr)
plt.show()

# %%
conll03 = [
    [84.39, 79.27, 81.75, 1],
    [83.42, 79.27, 81.29, 2],
    [84.27, 80.79, 82.49, 3],
    [84.53, 80.10, 82.25, 4],
    [82.84, 77.96, 80.32, 5],
    [84.53, 79.55, 81.97, 6],
]

df_conll03 = pd.DataFrame(conll03, columns=["prec.", "rec.", "f1", "#proto"])

plt.rcParams['figure.figsize'] = [4, 3]
sns.lineplot(x="#proto", y="f1", data=df_conll03)
plt.show()
